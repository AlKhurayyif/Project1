# %% [markdown]
# # Create DataFrame

# %%
df = pd.read_csv('C:/users/Ibrahim Al-Khurayyif/Project1/Data_M2008-2017.csv')

# %% [markdown]
# # 1. Business Understanding

# %% [markdown]
# # 2. Data Understanding

# %% [markdown]
# # 3. Prepare Data

# %% [markdown]
# ## 3.1 Import Libraries:

# %% [markdown]
# In this section, I will import all library it will be  useful.

# %%
import pandas as pd    
import numpy as np
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## 3.2 Create DataFrame:

# %% [markdown]
# #### In this section, I will create a dataframe of my study.

# %%
df = pd.read_csv('C:/users/Ibrahim Al-Khurayyif/Project1/Data_M2008-2017.csv')

# %%
df
# Out:
#       StationNumber StationName  Year  Month  Day  AirTemperatureMeanDB  \
# 0             41030      Makkah  2008      1    1                  26.7
# 1             41030      Makkah  2008      1    2                  26.4
# 2             41030      Makkah  2008      1    3                  26.2
# 3             41030      Makkah  2008      1    4                  25.2
# 4             41030      Makkah  2008      1    5                  23.8
# ...             ...         ...   ...    ...  ...                   ...
# 3578          41030      Makkah  2017     12   26                  27.2
# 3579          41030      Makkah  2017     12   27                  26.6
# 3580          41030      Makkah  2017     12   28                  27.4
# 3581          41030      Makkah  2017     12   29                  27.8
# 3582          41030      Makkah  2017     12   30                  27.6
#
#       AirTemperatureMaxDB  AirTemperatureMinDB WindPrevailingDirection  \
# 0                    33.8                 21.0                       S
# 1                    33.8                 21.0                     WSW
# 2                    33.0                 22.0                     WSW
# 3                    30.2                 22.4                       N
# 4                    30.4                 21.0                      NW
# ...                   ...                  ...                     ...
# 3578                 37.0                 21.2                    CALM
# 3579                 35.0                 20.6                       S
# 3580                 35.6                 22.6                     SSW
# 3581                 35.6                 23.0                     WSW
# 3582                 34.0                 23.4                     SSW
#
#       WindMeanSpeed  ...  RelativeHumidityMean  SkyCovOktesMean  \
# 0               2.0  ...                    65              0.6
# 1               1.0  ...                    65              0.3
# 2               1.0  ...                    72              1.9
# 3               1.0  ...                    65              3.5
# 4               1.0  ...                    57              3.4
# ...             ...  ...                   ...              ...
# 3578            0.0  ...                    53              1.3
# 3579            2.0  ...                    51              0.1
# 3580            1.0  ...                    63              0.2
# 3581            2.0  ...                    64              0.5
# 3582            2.0  ...                    67              0.4
#
#       RelativeHumidityMax  RelativeHumidityMin  PressureMinSeaLevel  \
# 0                      90                   39               1009.0
# 1                      87                   38               1010.3
# 2                      92                   42               1010.2
# 3                      89                   48               1012.3
# 4                      66                   42               1013.3
# ...                   ...                  ...                  ...
# 3578                   75                   24               1010.9
# 3579                   81                   38               1010.5
# 3580                   84                   33               1010.4
# 3581                   85                   32               1011.4
# 3582                   86                   39               1011.6
#
#       PressureMinStationLevel  PressureMaxStationLevel  PressureMaxSeaLevel  \
# 0                       982.0                    986.4               1013.4
# 1                       983.0                    986.3               1013.1
# 2                       983.3                    986.8               1013.9
# 3                       985.3                    988.7               1015.6
# 4                       986.0                    988.9               1016.0
# ...                       ...                      ...                  ...
# 3578                    983.4                    988.5               1015.8
# 3579                    983.5                    987.6               1014.5
# 3580                    983.7                    987.0               1013.8
# 3581                    984.7                    987.3               1014.4
# 3582                    984.7                    988.0               1014.6
#
#       PressureMeanStationLevel  PressureMeanSeaLevel
# 0                        984.2                1011.2
# 1                        984.7                1011.7
# 2                        985.0                1012.0
# 3                        986.7                1013.9
# 4                        987.6                1014.9
# ...                        ...                   ...
# 3578                     986.5                1013.4
# 3579                     985.5                1012.5
# 3580                     985.7                1012.6
# 3581                     986.3                1013.2
# 3582                     986.2                1013.2
#
# [3583 rows x 22 columns]

# %% [markdown]
# ## 3.3 Prepare DataFrame:

# %% [markdown]
# #### In this section, I will do two things:

# %% [markdown]
# #####    (A) Change the column name formatting style to "Capitalization".

# %% [markdown]
# #####    (B) Drop columns that will don't use them.

# %% [markdown]
# #####    (C) Create columns that will be useful for study.

# %% [markdown]
# #####    (D) Reorder columns.

# %% [markdown]
# ### 3.3.A Capitalization:

# %% [markdown]
# #### I will do that because the old column name formatting style is not comfortable.

# %%
df.columns = ['StationNumber', 'StationName', 'Year', 'Month', 'Day',
       'AirTemperatureMeanDB', 'AirTemperatureMaxDB',
       'AirTemperatureMinDB', 'WindPrevailingDirection',
       'WindMeanSpeed', 'WindMaxDirection', 'WindMaxSpeed',
       'RelativeHumidityMean', 'SkyCovOktesMean', 'RelativeHumidityMax',
       'RelativeHumidityMin', 'PressureMinSeaLevel',
       'PressureMinStationLevel', 'PressureMaxStationLevel',
       'PressureMaxSeaLevel', 'PressureMeanStationLevel',
       'PressureMeanSeaLevel']

# %%
df.columns
# Out:
# Index(['StationNumber', 'StationName', 'Year', 'Month', 'Day',
#        'AirTemperatureMeanDB', 'AirTemperatureMaxDB', 'AirTemperatureMinDB',
#        'WindPrevailingDirection', 'WindMeanSpeed', 'WindMaxDirection',
#        'WindMaxSpeed', 'RelativeHumidityMean', 'SkyCovOktesMean',
#        'RelativeHumidityMax', 'RelativeHumidityMin', 'PressureMinSeaLevel',
#        'PressureMinStationLevel', 'PressureMaxStationLevel',
#        'PressureMaxSeaLevel', 'PressureMeanStationLevel',
#        'PressureMeanSeaLevel'],
#       dtype='object')

# %% [markdown]
# ### 3.3.B Drop Columns:

# %% [markdown]
# #### In this section, I will drop some columns like: StationNumber, StationName or any columns is will not use.

# %%
df = df.drop(columns=['StationNumber', 'StationName'])

# %% [markdown]
# ### 3.3.C Create A New Column:

# %% [markdown]
# #### In this section, I will use 'to_datetime' tool from pandas to create a new column.

# %%
df['Date'] = pd.to_datetime(df["Year"].astype(str) + "-" + df["Month"].astype(str) + "-" + df["Day"].astype(str))

# %%
df
# Out:
#       Year  Month  Day  AirTemperatureMeanDB  AirTemperatureMaxDB  \
# 0     2008      1    1                  26.7                 33.8
# 1     2008      1    2                  26.4                 33.8
# 2     2008      1    3                  26.2                 33.0
# 3     2008      1    4                  25.2                 30.2
# 4     2008      1    5                  23.8                 30.4
# ...    ...    ...  ...                   ...                  ...
# 3578  2017     12   26                  27.2                 37.0
# 3579  2017     12   27                  26.6                 35.0
# 3580  2017     12   28                  27.4                 35.6
# 3581  2017     12   29                  27.8                 35.6
# 3582  2017     12   30                  27.6                 34.0
#
#       AirTemperatureMinDB WindPrevailingDirection  WindMeanSpeed  \
# 0                    21.0                       S            2.0
# 1                    21.0                     WSW            1.0
# 2                    22.0                     WSW            1.0
# 3                    22.4                       N            1.0
# 4                    21.0                      NW            1.0
# ...                   ...                     ...            ...
# 3578                 21.2                    CALM            0.0
# 3579                 20.6                       S            2.0
# 3580                 22.6                     SSW            1.0
# 3581                 23.0                     WSW            2.0
# 3582                 23.4                     SSW            2.0
#
#       WindMaxDirection  WindMaxSpeed  ...  RelativeHumidityMax  \
# 0                   19            10  ...                   90
# 1                   18             7  ...                   87
# 2                   23             9  ...                   92
# 3                   31             6  ...                   89
# 4                   27             5  ...                   66
# ...                ...           ...  ...                  ...
# 3578                24             4  ...                   75
# 3579                18             8  ...                   81
# 3580                24             6  ...                   84
# 3581                18            10  ...                   85
# 3582                21             8  ...                   86
#
#       RelativeHumidityMin  PressureMinSeaLevel  PressureMinStationLevel  \
# 0                      39               1009.0                    982.0
# 1                      38               1010.3                    983.0
# 2                      42               1010.2                    983.3
# 3                      48               1012.3                    985.3
# 4                      42               1013.3                    986.0
# ...                   ...                  ...                      ...
# 3578                   24               1010.9                    983.4
# 3579                   38               1010.5                    983.5
# 3580                   33               1010.4                    983.7
# 3581                   32               1011.4                    984.7
# 3582                   39               1011.6                    984.7
#
#       PressureMaxStationLevel  PressureMaxSeaLevel  PressureMeanStationLevel  \
# 0                       986.4               1013.4                     984.2
# 1                       986.3               1013.1                     984.7
# 2                       986.8               1013.9                     985.0
# 3                       988.7               1015.6                     986.7
# 4                       988.9               1016.0                     987.6
# ...                       ...                  ...                       ...
# 3578                    988.5               1015.8                     986.5
# 3579                    987.6               1014.5                     985.5
# 3580                    987.0               1013.8                     985.7
# 3581                    987.3               1014.4                     986.3
# 3582                    988.0               1014.6                     986.2
#
#       PressureMeanSeaLevel       date       Date
# 0                   1011.2 2008-01-01 2008-01-01
# 1                   1011.7 2008-01-02 2008-01-02
# 2                   1012.0 2008-01-03 2008-01-03
# 3                   1013.9 2008-01-04 2008-01-04
# 4                   1014.9 2008-01-05 2008-01-05
# ...                    ...        ...        ...
# 3578                1013.4 2017-12-26 2017-12-26
# 3579                1012.5 2017-12-27 2017-12-27
# 3580                1012.6 2017-12-28 2017-12-28
# 3581                1013.2 2017-12-29 2017-12-29
# 3582                1013.2 2017-12-30 2017-12-30
#
# [3583 rows x 22 columns]

# %% [markdown]
# ### 3.3.D Reorder The Columns:

# %% [markdown]
# #### In this section, I will reorder columns to facilitate reading.

# %%
df = df[['Date', 'AirTemperatureMeanDB', 'AirTemperatureMaxDB',
       'AirTemperatureMinDB', 'WindPrevailingDirection', 'WindMeanSpeed',
       'WindMaxDirection', 'WindMaxSpeed', 'RelativeHumidityMean',
       'SkyCovOktesMean', 'RelativeHumidityMax', 'RelativeHumidityMin',
       'PressureMinSeaLevel', 'PressureMinStationLevel',
       'PressureMaxStationLevel', 'PressureMaxSeaLevel',
       'PressureMeanStationLevel', 'PressureMeanSeaLevel', 'Year', 'Month', 'Day']]

# %%
df
# Out:
#            Date  AirTemperatureMeanDB  AirTemperatureMaxDB  \
# 0    2008-01-01                  26.7                 33.8
# 1    2008-01-02                  26.4                 33.8
# 2    2008-01-03                  26.2                 33.0
# 3    2008-01-04                  25.2                 30.2
# 4    2008-01-05                  23.8                 30.4
# ...         ...                   ...                  ...
# 3578 2017-12-26                  27.2                 37.0
# 3579 2017-12-27                  26.6                 35.0
# 3580 2017-12-28                  27.4                 35.6
# 3581 2017-12-29                  27.8                 35.6
# 3582 2017-12-30                  27.6                 34.0
#
#       AirTemperatureMinDB WindPrevailingDirection  WindMeanSpeed  \
# 0                    21.0                       S            2.0
# 1                    21.0                     WSW            1.0
# 2                    22.0                     WSW            1.0
# 3                    22.4                       N            1.0
# 4                    21.0                      NW            1.0
# ...                   ...                     ...            ...
# 3578                 21.2                    CALM            0.0
# 3579                 20.6                       S            2.0
# 3580                 22.6                     SSW            1.0
# 3581                 23.0                     WSW            2.0
# 3582                 23.4                     SSW            2.0
#
#       WindMaxDirection  WindMaxSpeed  RelativeHumidityMean  SkyCovOktesMean  \
# 0                   19            10                    65              0.6
# 1                   18             7                    65              0.3
# 2                   23             9                    72              1.9
# 3                   31             6                    65              3.5
# 4                   27             5                    57              3.4
# ...                ...           ...                   ...              ...
# 3578                24             4                    53              1.3
# 3579                18             8                    51              0.1
# 3580                24             6                    63              0.2
# 3581                18            10                    64              0.5
# 3582                21             8                    67              0.4
#
#       ...  RelativeHumidityMin  PressureMinSeaLevel  PressureMinStationLevel  \
# 0     ...                   39               1009.0                    982.0
# 1     ...                   38               1010.3                    983.0
# 2     ...                   42               1010.2                    983.3
# 3     ...                   48               1012.3                    985.3
# 4     ...                   42               1013.3                    986.0
# ...   ...                  ...                  ...                      ...
# 3578  ...                   24               1010.9                    983.4
# 3579  ...                   38               1010.5                    983.5
# 3580  ...                   33               1010.4                    983.7
# 3581  ...                   32               1011.4                    984.7
# 3582  ...                   39               1011.6                    984.7
#
#       PressureMaxStationLevel  PressureMaxSeaLevel  PressureMeanStationLevel  \
# 0                       986.4               1013.4                     984.2
# 1                       986.3               1013.1                     984.7
# 2                       986.8               1013.9                     985.0
# 3                       988.7               1015.6                     986.7
# 4                       988.9               1016.0                     987.6
# ...                       ...                  ...                       ...
# 3578                    988.5               1015.8                     986.5
# 3579                    987.6               1014.5                     985.5
# 3580                    987.0               1013.8                     985.7
# 3581                    987.3               1014.4                     986.3
# 3582                    988.0               1014.6                     986.2
#
#       PressureMeanSeaLevel  Year  Month  Day
# 0                   1011.2  2008      1    1
# 1                   1011.7  2008      1    2
# 2                   1012.0  2008      1    3
# 3                   1013.9  2008      1    4
# 4                   1014.9  2008      1    5
# ...                    ...   ...    ...  ...
# 3578                1013.4  2017     12   26
# 3579                1012.5  2017     12   27
# 3580                1012.6  2017     12   28
# 3581                1013.2  2017     12   29
# 3582                1013.2  2017     12   30
#
# [3583 rows x 21 columns]

# %% [markdown]
# #### Now I Finished The Third Process of CRISP-DM (Prepare Data).

# %% [markdown]
# # 4. Model Data

# %% [markdown]
# ##### Firstly, I will find mean of AirTemperatureMean by Month:

# %%
Temperature = df.groupby(['Year', 'Month']).agg({'AirTemperatureMeanDB':'mean'}).reset_index()

# %%
Temperature
# Out:
#      Year  Month  AirTemperatureMeanDB
# 0    2008      1             23.560000
# 1    2008      2             25.555172
# 2    2008      3             29.323333
# 3    2008      4             32.443333
# 4    2008      5             34.273333
# ..    ...    ...                   ...
# 115  2017      8             36.376667
# 116  2017      9             36.070000
# 117  2017     10             33.333333
# 118  2017     11             29.420000
# 119  2017     12             27.456667
#
# [120 rows x 3 columns]

# %%
Temperature = Temperature.pivot(index='Year', columns='Month', values='AirTemperatureMeanDB')
Temperature.columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Temperature = Temperature.reset_index()

# %%
Temperature
# Out:
#    Year        Jan        Feb        Mar        Apr        May        Jun  \
# 0  2008  23.560000  25.555172  29.323333  32.443333  34.273333  36.203333
# 1  2009  25.813333  26.782143  27.296667  31.923333  33.880000  36.983333
# 2  2010  25.326667  25.846429  28.540000  31.993333  34.363333  36.783333
# 3  2011  24.010000  25.846429  26.880000  30.646667  34.356667  35.936667
# 4  2012  23.553333  26.572414  27.296667  31.283333  35.510000  37.386667
# 5  2013  25.276667  27.314286  29.583333  30.826667  34.986667  36.983333
# 6  2014  25.650000  26.471429  28.780000  32.706667  34.053333  36.946667
# 7  2015  24.416667  26.560714  29.403333  30.836667  35.196667  35.966667
# 8  2016  24.396667  26.765517  31.540000  31.676667  35.530000  38.876667
# 9  2017  27.516667  26.178571  29.386667  33.320000  35.313333  37.013333
#
#          Jul        Aug        Sep        Oct        Nov        Dec
# 0  36.783333  36.166667  35.600000  32.430000  28.816667  26.706667
# 1  36.316667  35.736667  34.920000  32.153333  28.380000  25.493333
# 2  36.180000  36.666667  35.263333  34.290000  29.996667  26.833333
# 3  36.853333  35.843333  34.703333  32.826667  27.500000  26.413333
# 4  36.866667  36.163333  35.323333  32.576667  29.310000  26.460000
# 5  36.070000  34.963333  35.466667  33.046667  29.636667  25.913333
# 6  36.890000  36.523333  35.096667  32.596667  28.440000  27.310000
# 7  36.986667  37.386667  36.150000  33.793333  29.580000  25.246667
# 8  37.970000  36.753333  35.846667  33.236667  29.810000  28.240000
# 9  37.476667  36.376667  36.070000  33.333333  29.420000  27.456667

# %% [markdown]
# ###### Secondly, I will find mean of RelativeHumidityMean by Month:

# %%
Humidity = df.groupby(['Year', 'Month']).agg({'RelativeHumidityMean': 'mean'}).reset_index()

# %%
Humidity = Humidity.pivot(index='Year', columns='Month', values='RelativeHumidityMean')
Humidity.columns = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
Humidity = Humidity.reset_index()

# %%
Humidity
# Out:
#    Year        Jan        Feb        Mar        Apr        May        Jun  \
# 0  2008  58.133333  50.758621  42.666667  39.766667  31.333333  28.166667
# 1  2009  53.766667  55.964286  50.100000  38.066667  35.433333  30.766667
# 2  2010  57.933333  62.214286  51.433333  46.400000  38.233333  34.233333
# 3  2011  60.066667  53.714286  46.833333  39.833333  33.533333  33.500000
# 4  2012  55.133333  52.862069  44.566667  40.233333  30.566667  24.900000
# 5  2013  56.066667  51.642857  47.933333  39.800000  36.133333  24.566667
# 6  2014  59.233333  55.428571  47.533333  42.266667  39.933333  35.433333
# 7  2015  59.666667  58.750000  52.100000  41.733333  41.333333  35.166667
# 8  2016  63.400000  60.931034  52.800000  52.600000  47.533333  35.300000
# 9  2017  56.000000  49.142857  48.300000  41.133333  36.433333  35.100000
#
#          Jul        Aug        Sep        Oct        Nov        Dec
# 0  25.433333  31.766667  45.566667  44.266667  57.900000  50.666667
# 1  29.533333  41.000000  42.600000  50.166667  61.733333  66.200000
# 2  44.366667  43.266667  44.633333  38.566667  48.800000  53.633333
# 3  33.066667  36.700000  36.400000  49.800000  49.300000  52.933333
# 4  31.800000  33.833333  33.933333  49.133333  50.200000  54.366667
# 5  38.366667  43.033333  44.633333  50.333333  56.466667  58.500000
# 6  32.733333  39.200000  44.533333  53.666667  59.566667  66.000000
# 7  29.466667  44.000000  48.033333  50.666667  58.200000  58.100000
# 8  39.300000  48.100000  51.966667  56.166667  60.200000  56.100000
# 9  30.866667  45.233333  43.766667  47.966667  59.300000  52.700000

# %% [markdown]
# ###### Thirdly, I will calculate the overall average of temperature and humidity. Then, I will find the difference between each monthly average for both variables and the overall average:

# %%
Temp_mean = df.AirTemperatureMeanDB.mean()
Temp_mean
# Out:
# 31.761149874406946

# %%
Humi_mean = df.RelativeHumidityMean.mean()
Humi_mean
# Out:
# 45.98353335193971

# %%
Temp_delta = Temperature
Humi_delta = Humidity

# %%
Temp_delta.iloc[:, 1:] = Temp_delta.iloc[:, 1:].apply(lambda column: column - Temp_mean)
Humi_delta.iloc[:, 1:] = Humi_delta.iloc[:, 1:].apply(lambda column: column - Humi_mean)

# %%
Temp_delta
# Out:
#    Year       Jan       Feb       Mar       Apr       May       Jun       Jul  \
# 0  2008 -8.201150 -6.205977 -2.437817  0.682183  2.512183  4.442183  5.022183
# 1  2009 -5.947817 -4.979007 -4.464483  0.162183  2.118850  5.222183  4.555517
# 2  2010 -6.434483 -5.914721 -3.221150  0.232183  2.602183  5.022183  4.418850
# 3  2011 -7.751150 -5.914721 -4.881150 -1.114483  2.595517  4.175517  5.092183
# 4  2012 -8.207817 -5.188736 -4.464483 -0.477817  3.748850  5.625517  5.105517
# 5  2013 -6.484483 -4.446864 -2.177817 -0.934483  3.225517  5.222183  4.308850
# 6  2014 -6.111150 -5.289721 -2.981150  0.945517  2.292183  5.185517  5.128850
# 7  2015 -7.344483 -5.200436 -2.357817 -0.924483  3.435517  4.205517  5.225517
# 8  2016 -7.364483 -4.995633 -0.221150 -0.084483  3.768850  7.115517  6.208850
# 9  2017 -4.244483 -5.582578 -2.374483  1.558850  3.552183  5.252183  5.715517
#
#         Aug       Sep       Oct       Nov       Dec
# 0  4.405517  3.838850  0.668850 -2.944483 -5.054483
# 1  3.975517  3.158850  0.392183 -3.381150 -6.267817
# 2  4.905517  3.502183  2.528850 -1.764483 -4.927817
# 3  4.082183  2.942183  1.065517 -4.261150 -5.347817
# 4  4.402183  3.562183  0.815517 -2.451150 -5.301150
# 5  3.202183  3.705517  1.285517 -2.124483 -5.847817
# 6  4.762183  3.335517  0.835517 -3.321150 -4.451150
# 7  5.625517  4.388850  2.032183 -2.181150 -6.514483
# 8  4.992183  4.085517  1.475517 -1.951150 -3.521150
# 9  4.615517  4.308850  1.572183 -2.341150 -4.304483

# %% [markdown]
# ### Plotting

# %%
Humi_mean = df.RelativeHumidityMean.mean()
Humi_mean
# Out:
# 45.98353335193971

# %%
fig = px.line(df, x='Date', y='AirTemperatureMeanDB')
fig.add_hline(y=31.761149874406946)
fig.show()
# Out:
# <div>                            <div id="40e6193e-2ade-4d00-b2c8-da70fb773704" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40e6193e-2ade-4d00-b2c8-da70fb773704")) {                    Plotly.newPlot(                        "40e6193e-2ade-4d00-b2c8-da70fb773704",                        [{"hovertemplate":"Date=%{x}<br>AirTemperatureMeanDB=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2008-01-01T00:00:00","2008-01-02T00:00:00","2008-01-03T00:00:00","2008-01-04T00:00:00","2008-01-05T00:00:00","2008-01-06T00:00:00","2008-01-07T00:00:00","2008-01-08T00:00:00","2008-01-09T00:00:00","2008-01-10T00:00:00","2008-01-11T00:00:00","2008-01-12T00:00:00","2008-01-13T00:00:00","2008-01-14T00:00:00","2008-01-15T00:00:00","2008-01-16T00:00:00","2008-01-17T00:00:00","2008-01-18T00:00:00","2008-01-19T00:00:00","2008-01-20T00:00:00","2008-01-21T00:00:00","2008-01-22T00:00:00","2008-01-23T00:00:00","2008-01-24T00:00:00","2008-01-25T00:00:00","2008-01-26T00:00:00","2008-01-27T00:00:00","2008-01-28T00:00:00","2008-01-29T00:00:00","2008-01-30T00:00:00","2008-02-01T00:00:00","2008-02-02T00:00:00","2008-02-03T00:00:00","2008-02-04T00:00:00","2008-02-05T00:00:00","2008-02-06T00:00:00","2008-02-07T00:00:00","2008-02-08T00:00:00","2008-02-09T00:00:00","2008-02-10T00:00:00","2008-02-11T00:00:00","2008-02-12T00:00:00","2008-02-13T00:00:00","2008-02-14T00:00:00","2008-02-15T00:00:00","2008-02-16T00:00:00","2008-02-17T00:00:00","2008-02-18T00:00:00","2008-02-19T00:00:00","2008-02-20T00:00:00","2008-02-21T00:00:00","2008-02-22T00:00:00","2008-02-23T00:00:00","2008-02-24T00:00:00","2008-02-25T00:00:00","2008-02-26T00:00:00","2008-02-27T00:00:00","2008-02-28T00:00:00","2008-02-29T00:00:00","2008-03-01T00:00:00","2008-03-02T00:00:00","2008-03-03T00:00:00","
orientation":"v","showlegend":true,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[-3.316866685273048,4.116466648060289,5.4497999813936175,0.8497999813936232,-1.4168666852730425,1.9497999813936175,1.549799981393619,6.116466648060289,6.816466648060285,2.3164666480602847],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Apr<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Apr","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Apr","orientation":"v","showlegend":true,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[-6.216866685273047,-7.9168666852730425,0.4164666480602861,-6.150200018606377,-5.750200018606378,-6.183533351939715,-3.7168666852730468,-4.250200018606378,6.616466648060289,-4.85020001860638],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=May<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"May","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"May","orientation":"v","showlegend":true,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[-14.65020001860638,-10.550200018606382,-7.750200018606378,-12.450200018606381,-15.416866685273046,-9.85020001860638,-6.0502000186063825,-4.650200018606377,1.549799981393619,-9.550200018606382],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Jun<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Jun","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Jun","orientation":"v","showlegend":true,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[-17.816866685273045,-15.216866685273047,-11.750200018606378,-12.483533351939712,-21.083533351939714,-21.416866685273046,-10.550200018606382,-10.816866685273048,-10.683533351939715,-10.883533351939711],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Jul<br>Year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Jul","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Jul","orientation":"v","showlegend":true,"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[-20.55020001860638,-16.4502000 ...

# %%
df_comp = Temperature.merge(Humidity, on='Year')
df_comp.columns = ['Year', 'Jan_Temp', 'Feb_Temp', 'Mar_Temp', 'Apr_Temp', 'May_Temp', 'Jun_Temp', 'Jul_Temp',
       'Aug_Temp', 'Sep_Temp', 'Oct_Temp', 'Nov_Temp', 'Dec_Temp', 'Jan_Humi', 'Feb_Humi', 'Mar_Humi',
       'Apr_Humi', 'May_Humi', 'Jun_Humi', 'Jul_Humi', 'Aug_Humi', 'Sep_Humi', 'Oct_Humi', 'Nov_Humi',
       'Dec_Humi']

# %%
df_comp = df_comp[[
    'Year', 'Jan_Temp',  'Jan_Humi', 'Feb_Temp', 'Feb_Humi', 'Mar_Temp', 'Mar_Humi', 'Apr_Temp', 'Apr_Humi',
    'May_Temp', 'May_Humi', 'Jun_Temp', 'Jun_Humi', 'Jul_Temp', 'Jul_Humi', 'Aug_Temp', 'Aug_Humi', 'Sep_Temp',
    'Sep_Humi', 'Oct_Temp', 'Oct_Humi', 'Nov_Temp', 'Nov_Humi', 'Dec_Temp',  'Dec_Humi'
]]

# %%
df_comp[['Year', 'Jan_Temp' , 'Jan_Humi']].corr()
# Out:
#               Year  Jan_Temp  Jan_Humi
# Year      1.000000  0.417410  0.359994
# Jan_Temp  0.417410  1.000000 -0.341264
# Jan_Humi  0.359994 -0.341264  1.000000

# %%
df_comp[['Year', 'Apr_Temp' , 'Apr_Humi']].corr()
# Out:
#               Year  Apr_Temp  Apr_Humi
# Year      1.000000  0.126314  0.417626
# Apr_Temp  0.126314  1.000000  0.070708
# Apr_Humi  0.417626  0.070708  1.000000

# %%
df_comp[['Year', 'Jul_Temp' , 'Jul_Humi']].corr()
df_comp[['Year', 'Jul_Temp' , 'Jul_Humi']].corr()
# Out:
#               Year  Jul_Temp  Jul_Humi
# Year      1.000000  0.671087  0.158137
# Jul_Temp  0.671087  1.000000 -0.143473
# Jul_Humi  0.158137 -0.143473  1.000000

# %%
fig = px.line(Temperature, x='Year', y=Temperature.drop(columns='Year').columns)
fig.show()

# %%
fig = px.line(Humidity, x='Year', y=Humidity.drop(columns='Year').columns)
fig.show()
